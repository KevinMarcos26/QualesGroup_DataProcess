# %% [markdown]
# # **Capacitación Data Process Desafío 1**
#
# ![Captura2.PNG](data:image/png;base64,...)

# %% [markdown]
# ## **Desafío**
#
# Dado el archivo compartido **Concesionarias**, identificar las columnas que son
# Atributos y aquellas que son Indicadores.
#
# Armar un diseño lógico con las Dimensiones y Tablas de Hechos
# Identificadas. Identificar qué tipo de modelo es.
#
# Sugerencias de uso de herramientas:
# ● jamboard de Google: https://jamboard.google.com/u/0/ .
# ● dbdiagram: https://dbdiagram.io/
#
# ● Drawio.net: https://app.diagrams.net/

# %% [markdown]
# ## **Obtención del archivo**

# %%
import pandas as pd

# %%
concesionarias = pd.read_excel("/content/Date Set Clase 2 - Concesionarias.xlsx")

# %%
concesionarias.head()
# Out:
#         Marca  Monto Vendido  Modelo Concesionaria     Dirección Sucursal  \
# 0        Ford      1500000.0  Fiesta          Suc1   Ciudad de la Paz 155
# 1     Citroen      2358000.0      C4          Suc2  Hipolito Yrigoyen 511
# 2  Chevrolet       2100000.0   Cruze          Suc2  Hipolito Yrigoyen 511
#
#       Provincia     Fecha   Cantidad Vendida       Color  Total IVA      Mes  \
# 0  Buenos Aires 2019-01-01               2.0        Rojo     315000  January
# 1       Córdoba 2021-01-01               1.0  Gris Plata     495180  January
# 2       Córdoba 2021-01-01               1.0       Negro     441000  January
#
#     Año
# 0  2019
# 1  2021
# 2  2021

# %%
concesionarias.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Marca               3 non-null      object
#  1   Monto Vendido       3 non-null      float64
#  2   Modelo              3 non-null      object
#  3   Concesionaria       3 non-null      object
#  4   Dirección Sucursal  3 non-null      object
#  5   Provincia           3 non-null      object
#  6   Fecha               3 non-null      datetime64[ns]
#  7   Cantidad Vendida    3 non-null      float64
#  8   Color               3 non-null      object
#  9   Total IVA           3 non-null      int64
#  10  Mes                 3 non-null      object
#  11  Año                 3 non-null      int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(7)
# memory usage: 416.0+ bytes

# %% [markdown]
# ## **Modelado de Datos**

# %% [markdown]
# **Columnas que son Atributos**
#
# > Marca
#
# > Modelo
#
# > Concesionaria
#
# > Dirección Sucursal
#
# > Provincia
#
# > Fecha
#
# > Color
#
# > Mes
#
# > Año
#
# **Columnas que son Indicadores**
#
# > Monto Vendido
#
# > Cantidad Vendida
#
# > Total IVA

# %% [markdown]
# **MODELO DIMENSIONAL - MODELO ESTRELLA(STAR)**

# %% [markdown]
# HECHOS Y DIMENSIONES
#
# ![modelo.PNG](data:image/png;base64,...)

# %% [markdown]
# MODELO LÓGICO
#
# ![1.PNG](data:image/png;base64,...)
